# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("PZ4-IngestaTest")
    .config("spark.driver.extraClassPath", "/opt/jars/postgresql-42.7.4.jar")
    .config("spark.jars", "/opt/jars/postgresql-42.7.4.jar")
    .getOrCreate()
)

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://0.0.0.0:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PZ4-IngestaTest</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# %pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.11-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Downloading psycopg2_binary-2.9.11-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 28.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.11
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from datetime import datetime, timezone
from pyspark.sql import functions as F
import psycopg2

# Config
DATA_ROOT = "/home/jovyan/work/data/trip-data"
service = "yellow"
year, month = 2015, 1

PG_HOST = os.getenv("PG_HOST", "postgres")
PG_PORT = os.getenv("PG_PORT", "5432")
PG_DB   = os.getenv("PG_DB", "nyctaxi")
PG_USER = os.getenv("PG_USER", "pset")
PG_PWD  = os.getenv("PG_PASSWORD", "pset_password")
PG_URL  = f"jdbc:postgresql://{PG_HOST}:{PG_PORT}/{PG_DB}"
PG_PROPS = {"driver": "org.postgresql.Driver", "user": PG_USER, "password": PG_PWD}

# 1) Borrar partición previa en Postgres (idempotencia)
conn = psycopg2.connect(
    host=PG_HOST,
    port=PG_PORT,
    dbname=PG_DB,
    user=PG_USER,
    password=PG_PWD,
)
cur = conn.cursor()
cur.execute(
    "DELETE FROM raw.yellow_taxi_trip WHERE source_year=%s AND source_month=%s;",
    (year, month),
)
deleted = cur.rowcount
conn.commit()
cur.close()
conn.close()
print(f"BORRADOS anteriores: {deleted} filas de yellow {year}-{month:02d}")

# 2) Leer parquet
fname = f"{service}_tripdata_{year}-{month:02d}.parquet"
path  = f"{DATA_ROOT}/{fname}"
print("Leyendo parquet:", path)
df = spark.read.parquet(path)

# 3) Normalización mínima + metadatos
run_id = datetime.now(timezone.utc).strftime("ingest-%Y%m%dT%H%M%SZ")

dfn = (df
    .withColumnRenamed("tpep_pickup_datetime",  "pickup_datetime")
    .withColumnRenamed("tpep_dropoff_datetime", "dropoff_datetime")
    .withColumn("service_type",    F.lit(service))
    .withColumn("source_year",     F.lit(int(year)))
    .withColumn("source_month",    F.lit(int(month)))
    .withColumn("ingested_at_utc", F.lit(datetime.now(timezone.utc)))
    .withColumn("run_id",          F.lit(run_id))
)

# 4) Escribir a Postgres (append)
table = "raw.yellow_taxi_trip"
(dfn.write
    .mode("append")
    .jdbc(PG_URL, table, properties=PG_PROPS))

cnt = dfn.count()
print(f"INSERTADAS: {cnt} filas nuevas en {table} para {year}-{month:02d}")

# 5) Verificar conteo final directamente en Postgres
conn = psycopg2.connect(
    host=PG_HOST,
    port=PG_PORT,
    dbname=PG_DB,
    user=PG_USER,
    password=PG_PWD,
)
cur = conn.cursor()
cur.execute(
    "SELECT COUNT(*) FROM raw.yellow_taxi_trip WHERE source_year=%s AND source_month=%s;",
    (year, month),
)
final_cnt = cur.fetchone()[0]
cur.close()
conn.close()
print(f"COUNT final en Postgres (yellow {year}-{month:02d}): {final_cnt}")
# Out:
# BORRADOS anteriores: 0 filas de yellow 2015-01
# Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2015-01.parquet
# INSERTADAS: 12741035 filas nuevas en raw.yellow_taxi_trip para 2015-01
# COUNT final en Postgres (yellow 2015-01): 12741035

# %%
path = "/home/jovyan/work/data/trip-data/green_tripdata_2015-01.parquet"
dfg = spark.read.parquet(path)

dfg.printSchema()
# Out:
# root
#  |-- VendorID: long (nullable = true)
#  |-- lpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- lpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- PULocationID: long (nullable = true)
#  |-- DOLocationID: long (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- ehail_fee: integer (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- trip_type: double (nullable = true)
#  |-- congestion_surcharge: integer (nullable = true)

# %%
import os
from datetime import datetime, timezone
from pyspark.sql import functions as F
import psycopg2

# Config
DATA_ROOT = "/home/jovyan/work/data/trip-data"
service = "green"
year, month = 2015, 1

PG_HOST = os.getenv("PG_HOST", "postgres")
PG_PORT = os.getenv("PG_PORT", "5432")
PG_DB   = os.getenv("PG_DB", "nyctaxi")
PG_USER = os.getenv("PG_USER", "pset")
PG_PWD  = os.getenv("PG_PASSWORD", "pset_password")
PG_URL  = f"jdbc:postgresql://{PG_HOST}:{PG_PORT}/{PG_DB}"
PG_PROPS = {"driver": "org.postgresql.Driver", "user": PG_USER, "password": PG_PWD}

# 1) Borrar partición previa SOLO si la tabla ya existe
conn = psycopg2.connect(
    host=PG_HOST,
    port=PG_PORT,
    dbname=PG_DB,
    user=PG_USER,
    password=PG_PWD,
)
cur = conn.cursor()

cur.execute("""
    SELECT EXISTS (
      SELECT 1
      FROM information_schema.tables
      WHERE table_schema = 'raw'
        AND table_name   = 'green_taxi_trip'
    );
""")
exists = cur.fetchone()[0]

if exists:
    cur.execute(
        "DELETE FROM raw.green_taxi_trip WHERE source_year=%s AND source_month=%s;",
        (year, month),
    )
    deleted = cur.rowcount
    print(f"BORRADOS anteriores: {deleted} filas de green {year}-{month:02d}")
else:
    print("Tabla raw.green_taxi_trip aún no existe; no hay nada que borrar.")

conn.commit()
cur.close()
conn.close()

# 2) Leer parquet
fname = f"{service}_tripdata_{year}-{month:02d}.parquet"
path  = f"{DATA_ROOT}/{fname}"
print("Leyendo parquet:", path)
df = spark.read.parquet(path)

# 3) Normalización mínima + metadatos
run_id = datetime.now(timezone.utc).strftime("ingest-%Y%m%dT%H%M%SZ")

dfn = (df
    .withColumnRenamed("lpep_pickup_datetime",  "pickup_datetime")
    .withColumnRenamed("lpep_dropoff_datetime", "dropoff_datetime")
    .withColumn("service_type",    F.lit(service))
    .withColumn("source_year",     F.lit(int(year)))
    .withColumn("source_month",    F.lit(int(month)))
    .withColumn("ingested_at_utc", F.lit(datetime.now(timezone.utc)))
    .withColumn("run_id",          F.lit(run_id))
)

# 4) Escribir a Postgres (append)
table = "raw.green_taxi_trip"
(dfn.write
    .mode("append")
    .jdbc(PG_URL, table, properties=PG_PROPS))

cnt = dfn.count()
print(f"INSERTADAS: {cnt} filas nuevas en {table} para {year}-{month:02d}")

# 5) Verificar conteo final directamente en Postgres
conn = psycopg2.connect(
    host=PG_HOST,
    port=PG_PORT,
    dbname=PG_DB,
    user=PG_USER,
    password=PG_PWD,
)
cur = conn.cursor()
cur.execute(
    "SELECT COUNT(*) FROM raw.green_taxi_trip WHERE source_year=%s AND source_month=%s;",
    (year, month),
)
final_cnt = cur.fetchone()[0]
cur.close()
conn.close()
print(f"COUNT final en Postgres (green {year}-{month:02d}): {final_cnt}")
# Out:
# Tabla raw.green_taxi_trip aún no existe; no hay nada que borrar.
# Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2015-01.parquet
# INSERTADAS: 1508493 filas nuevas en raw.green_taxi_trip para 2015-01
# COUNT final en Postgres (green 2015-01): 1508493

# %%
def ingest_month(service: str, year: int, month: int):
    """
    Ingesta idempotente de un (service, year, month) desde parquet → raw.<service>_taxi_trip.
    service: 'yellow' o 'green'
    """
    import os
    from datetime import datetime, timezone
    import psycopg2
    from pyspark.sql import functions as F

    DATA_ROOT = "/home/jovyan/work/data/trip-data"

    PG_HOST = os.getenv("PG_HOST", "postgres")
    PG_PORT = os.getenv("PG_PORT", "5432")
    PG_DB   = os.getenv("PG_DB", "nyctaxi")
    PG_USER = os.getenv("PG_USER", "pset")
    PG_PWD  = os.getenv("PG_PASSWORD", "pset_password")

    # 👇 CAMBIO 1: activamos reWriteBatchedInserts en el JDBC URL
    PG_URL  = f"jdbc:postgresql://{PG_HOST}:{PG_PORT}/{PG_DB}?reWriteBatchedInserts=true"
    PG_PROPS = {"driver": "org.postgresql.Driver", "user": PG_USER, "password": PG_PWD}

    # 1) Borrar partición previa solo si la tabla existe
    conn = psycopg2.connect(
        host=PG_HOST,
        port=PG_PORT,
        dbname=PG_DB,
        user=PG_USER,
        password=PG_PWD,
    )
    cur = conn.cursor()
    table_name = f"{service}_taxi_trip"

    cur.execute("""
        SELECT EXISTS (
          SELECT 1
          FROM information_schema.tables
          WHERE table_schema = 'raw'
            AND table_name   = %s
        );
    """, (table_name,))
    exists = cur.fetchone()[0]

    if exists:
        cur.execute(
            f"DELETE FROM raw.{table_name} WHERE source_year=%s AND source_month=%s;",
            (year, month),
        )
        deleted = cur.rowcount
        print(f"[{service} {year}-{month:02d}] BORRADOS anteriores: {deleted}")
    else:
        print(f"[{service} {year}-{month:02d}] Tabla raw.{table_name} aún no existe; no hay nada que borrar.")

    conn.commit()
    cur.close()
    conn.close()

    # 2) Leer parquet
    fname = f"{service}_tripdata_{year}-{month:02d}.parquet"
    path  = f"{DATA_ROOT}/{fname}"
    print(f"[{service} {year}-{month:02d}] Leyendo parquet: {path}")
    df = spark.read.parquet(path)

    # 3) Normalizar timestamps según servicio
    run_id = datetime.now(timezone.utc).strftime("ingest-%Y%m%dT%H%M%SZ")

    if service == "yellow":
        df = (df
            .withColumnRenamed("tpep_pickup_datetime",  "pickup_datetime")
            .withColumnRenamed("tpep_dropoff_datetime", "dropoff_datetime")
        )
    elif service == "green":
        df = (df
            .withColumnRenamed("lpep_pickup_datetime",  "pickup_datetime")
            .withColumnRenamed("lpep_dropoff_datetime", "dropoff_datetime")
        )
    else:
        raise ValueError(f"Servicio no soportado: {service}")

    dfn = (df
        .withColumn("service_type",    F.lit(service))
        .withColumn("source_year",     F.lit(int(year)))
        .withColumn("source_month",    F.lit(int(month)))
        .withColumn("ingested_at_utc", F.lit(datetime.now(timezone.utc)))
        .withColumn("run_id",          F.lit(run_id))
    )

    # 4) Escribir a Postgres (optimizado)
    table = f"raw.{service}_taxi_trip"
    (dfn.write
        .mode("append")
        .option("batchsize", 10000)     # 👈 CAMBIO 2: batches más grandes
        .option("numPartitions", 8)     # 👈 CAMBIO 3: control de paralelismo JDBC
        .jdbc(PG_URL, table, properties=PG_PROPS))

    cnt = dfn.count()
    print(f"[{service} {year}-{month:02d}] INSERTADAS: {cnt} filas")

    return cnt

# %%
ingest_month("yellow", 2015, 2)
# Out:
# [yellow 2015-02] BORRADOS anteriores: 0
# [yellow 2015-02] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2015-02.parquet
# [yellow 2015-02] INSERTADAS: 12442394 filas
# 12442394

# %%
ingest_month("green", 2015, 2)
# Out:
# [green 2015-02] BORRADOS anteriores: 0
# [green 2015-02] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2015-02.parquet
# [green 2015-02] INSERTADAS: 1574830 filas
# 1574830

# %%
import os
import pandas as pd
from pyspark.sql import functions as F
from datetime import datetime, timezone

DATA_ROOT = "/home/jovyan/work/data/trip-data"
zones_path = os.path.join(DATA_ROOT, "taxi_zone_lookup.csv")

PG_HOST = os.getenv("PG_HOST", "postgres")
PG_PORT = os.getenv("PG_PORT", "5432")
PG_DB   = os.getenv("PG_DB", "nyctaxi")
PG_USER = os.getenv("PG_USER", "pset")
PG_PWD  = os.getenv("PG_PASSWORD", "pset_password")
PG_URL  = f"jdbc:postgresql://{PG_HOST}:{PG_PORT}/{PG_DB}"
PG_PROPS = {"driver": "org.postgresql.Driver", "user": PG_USER, "password": PG_PWD}

print("Leyendo CSV:", zones_path)
pdf = pd.read_csv(zones_path)

run_id = datetime.now(timezone.utc).strftime("zones-%Y%m%dT%H%M%SZ")

sdf = (spark.createDataFrame(pdf)
       .withColumn("ingested_at_utc", F.lit(datetime.now(timezone.utc)))
       .withColumn("run_id", F.lit(run_id)))

# overwrite porque es una tabla de catálogo chica
table = "raw.taxi_zone_lookup"
sdf.write.mode("overwrite").jdbc(PG_URL, table, properties=PG_PROPS)

print(f"Cargadas {sdf.count()} filas en {table}")
# Out:
# Leyendo CSV: /home/jovyan/work/data/trip-data/taxi_zone_lookup.csv
# Cargadas 265 filas en raw.taxi_zone_lookup

# %%
import time
from datetime import timedelta

services = ["yellow", "green"]
year = 2015
months = list(range(1, 13))

resumen = []
total_jobs = len(services) * len(months)
done = 0
start_global = time.time()

print(f"== Iniciando ingesta año {year} ==")

for svc in services:
    for m in months:
        print("\n" + "="*70)
        print(f">>> Ingestando {svc.upper()} {year}-{m:02d}")
        
        start = time.time()
        cnt = ingest_month(svc, year, m)
        elapsed = time.time() - start

        done += 1
        global_elapsed = time.time() - start_global
        avg_per_job = global_elapsed / done
        remaining_jobs = total_jobs - done
        eta = remaining_jobs * avg_per_job

        print(f"{svc} {year}-{m:02d}: {cnt} filas")
        print(f"Tiempo: {timedelta(seconds=int(elapsed))}")
        print(f"Progreso: {done}/{total_jobs}")
        print(f"ETA aproximada: {timedelta(seconds=int(eta))}")

        # Barra de progreso
        bar_length = 50
        filled = int(bar_length * done / total_jobs)
        bar = "█" * filled + "-" * (bar_length - filled)
        print(f"[{bar}]")

        resumen.append((svc, year, m, cnt))

print("\n== RESUMEN FINAL 2015 ==")
for svc, y, m, cnt in resumen:
    print(f"{svc} {y}-{m:02d}: {cnt} filas")

print("\nDuración total:", timedelta(seconds=int(time.time() - start_global)))
# Out:
# == Iniciando ingesta año 2015 ==
#
# ======================================================================
# >>> Ingestando YELLOW 2015-01
# [yellow 2015-01] BORRADOS anteriores: 12741035
# [yellow 2015-01] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2015-01.parquet
# [yellow 2015-01] INSERTADAS: 12741035 filas
# yellow 2015-01: 12741035 filas
# Tiempo: 0:07:09
# Progreso: 1/24
# ETA aproximada: 2:44:36
# [██------------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2015-02
# [yellow 2015-02] BORRADOS anteriores: 12442394
# [yellow 2015-02] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2015-02.parquet
# [yellow 2015-02] INSERTADAS: 12442394 filas
# yellow 2015-02: 12442394 filas
# Tiempo: 0:06:55
# Progreso: 2/24
# ETA aproximada: 2:34:54
# [████----------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2015-03
# [yellow 2015-03] BORRADOS anteriores: 0
# [yellow 2015-03] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2015-03.parquet
# [yellow 2015-03] INSERTADAS: 13342951 filas
# yellow 2015-03: 13342951 filas
# Tiempo: 0:07:05
# Progreso: 3/24
# ETA aproximada: 2:28:13
# [██████--------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2015-04
# [yellow 2015-04] BORRADOS anteriores: 0
# [yellow 2015-04] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2015-04.parquet
# [yellow 2015-04] INSERTADAS: 13063758 filas
# yellow 2015-04: 13063758 filas
# Tiempo: 0:06:53
# Progreso: 4/24
# ETA aproximada: 2:20:18
# [████████------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2015-05
# [yellow 2015-05] BORRADOS anteriores: 0
# [yellow 2015-05] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2015-05.parquet
# [yellow 2015-05] INSERTADAS: 13157677 filas
# yellow 2015-05: 13157677 filas
# Tiempo: 0:07:11
# Progreso: 5/24
# ETA aproximada: 2:13:56
# [██████████----------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2015-06
# [yellow 2015-06] BORRADOS anteriores: 0
# [yellow 2015-06] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2015-06.parquet
# [yellow 2015-06] INSERTADAS: 12324936 filas
# yellow 2015-06: 12324936 filas
# Tiempo: 0:06:40
# Progreso: 6/24
# ETA aproximada: 2:05:45
# [████████████--------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2015-07
# [yellow 2015-07] BORRADOS anteriores: 0
# [yellow 2015-07] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2015-07.parquet
# [yellow 2015-07] INSERTADAS: 11559666 filas
# yellow 2015-07: 11559666 filas
# Tiempo: 0:06:14
# Progreso: 7/24
# ETA aproximada: 1:56:59
# [██████████████------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2015-08
# [yellow 2015-08] BORRADOS anteriores: 0
# [yellow 2015-08] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2015-08.parquet
# [yellow 2015-08] INSERTADAS: 11123123 filas
# yellow 2015-08: 11123123 filas
# Tiempo: 0:06:01
# Progreso: 8/24
# ETA aproximada: 1:48:23
# [████████████████----------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2015-09
# [yellow 2015-09] BORRADOS anteriores: 0
# [yellow 2015-09] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2015-09.parquet
# [yellow 2015-09] INSERTADAS: 11218122 filas
# yellow 2015-09: 11218122 filas
# Tiempo: 0:06:06
# Progreso: 9/24
# ETA aproximada: 1:40:30
# [██████████████████--------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2015-10
# [yellow 2015-10] BORRADOS anteriores: 0
# [yellow 2015-10] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2015-10.parquet
# [yellow 2015-10] INSERTADAS: 12307333 filas
# yellow 2015-10: 12307333 filas
# Tiempo: 0:06:40
# Progreso: 10/24
# ETA aproximada: 1:33:46
# [████████████████████------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2015-11
# [yellow 2015-11] BORRADOS anteriores: 0
# [yellow 2015-11] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2015-11.parquet
# [yellow 2015-11] INSERTADAS: 11305240 filas
# yellow 2015-11: 11305240 filas
# Tiempo: 0:06:14
# Progreso: 11/24
# ETA aproximada: 1:26:32
# [██████████████████████----------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2015-12
# [yellow 2015-12] BORRADOS anteriores: 0
# [yellow 2015-12] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2015-12.parquet
# [yellow 2015-12] INSERTADAS: 11452996 filas
# yellow 2015-12: 11452996 filas
# Tiempo: 0:06:18
# Progreso: 12/24
# ETA aproximada: 1:19:31
# [█████████████████████████-------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2015-01
# [green 2015-01] BORRADOS anteriores: 1508493
# [green 2015-01] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2015-01.parquet
# [green 2015-01] INSERTADAS: 1508493 filas
# green 2015-01: 1508493 filas
# Tiempo: 0:00:52
# Progreso: 13/24
# ETA aproximada: 1:08:01
# [███████████████████████████-----------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2015-02
# [green 2015-02] BORRADOS anteriores: 1574830
# [green 2015-02] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2015-02.parquet
# [green 2015-02] INSERTADAS: 1574830 filas
# green 2015-02: 1574830 filas
# Tiempo: 0:00:55
# Progreso: 14/24
# ETA aproximada: 0:58:05
# [█████████████████████████████---------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2015-03
# [green 2015-03] BORRADOS anteriores: 0
# [green 2015-03] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2015-03.parquet
# [green 2015-03] INSERTADAS: 1722574 filas
# green 2015-03: 1722574 filas
# Tiempo: 0:00:57
# Progreso: 15/24
# ETA aproximada: 0:49:22
# [███████████████████████████████-------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2015-04
# [green 2015-04] BORRADOS anteriores: 0
# [green 2015-04] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2015-04.parquet
# [green 2015-04] INSERTADAS: 1664394 filas
# green 2015-04: 1664394 filas
# Tiempo: 0:00:55
# Progreso: 16/24
# ETA aproximada: 0:41:35
# [█████████████████████████████████-----------------]
#
# ======================================================================
# >>> Ingestando GREEN 2015-05
# [green 2015-05] BORRADOS anteriores: 0
# [green 2015-05] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2015-05.parquet
# [green 2015-05] INSERTADAS: 1786848 filas
# green 2015-05: 1786848 filas
# Tiempo: 0:01:00
# Progreso: 17/24
# ETA aproximada: 0:34:40
# [███████████████████████████████████---------------]
#
# ======================================================================
# >>> Ingestando GREEN 2015-06
# [green 2015-06] BORRADOS anteriores: 0
# [green 2015-06] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2015-06.parquet
# [green 2015-06] INSERTADAS: 1638868 filas
# green 2015-06: 1638868 filas
# Tiempo: 0:00:56
# Progreso: 18/24
# ETA aproximada: 0:28:22
# [█████████████████████████████████████-------------]
#
# ======================================================================
# >>> Ingestando GREEN 2015-07
# [green 2015-07] BORRADOS anteriores: 0
# [green 2015-07] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2015-07.parquet
# [green 2015-07] INSERTADAS: 1541671 filas
# green 2015-07: 1541671 filas
# Tiempo: 0:00:52
# Progreso: 19/24
# ETA aproximada: 0:22:38
# [███████████████████████████████████████-----------]
#
# ======================================================================
# >>> Ingestando GREEN 2015-08
# [green 2015-08] BORRADOS anteriores: 0
# [green 2015-08] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2015-08.parquet
# [green 2015-08] INSERTADAS: 1532343 filas
# green 2015-08: 1532343 filas
# Tiempo: 0:00:53
# Progreso: 20/24
# ETA aproximada: 0:17:22
# [█████████████████████████████████████████---------]
#
# ======================================================================
# >>> Ingestando GREEN 2015-09
# [green 2015-09] BORRADOS anteriores: 0
# [green 2015-09] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2015-09.parquet
# [green 2015-09] INSERTADAS: 1494927 filas
# green 2015-09: 1494927 filas
# Tiempo: 0:00:50
# Progreso: 21/24
# ETA aproximada: 0:12:32
# [███████████████████████████████████████████-------]
#
# ======================================================================
# >>> Ingestando GREEN 2015-10
# [green 2015-10] BORRADOS anteriores: 0
# [green 2015-10] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2015-10.parquet
# [green 2015-10] INSERTADAS: 1630536 filas
# green 2015-10: 1630536 filas
# Tiempo: 0:00:55
# Progreso: 22/24
# ETA aproximada: 0:08:03
# [█████████████████████████████████████████████-----]
#
# ======================================================================
# >>> Ingestando GREEN 2015-11
# [green 2015-11] BORRADOS anteriores: 0
# [green 2015-11] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2015-11.parquet
# [green 2015-11] INSERTADAS: 1529984 filas
# green 2015-11: 1529984 filas
# Tiempo: 0:00:54
# Progreso: 23/24
# ETA aproximada: 0:03:53
# [███████████████████████████████████████████████---]
#
# ======================================================================
# >>> Ingestando GREEN 2015-12
# [green 2015-12] BORRADOS anteriores: 0
# [green 2015-12] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2015-12.parquet
# [green 2015-12] INSERTADAS: 1608297 filas
# green 2015-12: 1608297 filas
# Tiempo: 0:00:55
# Progreso: 24/24
# ETA aproximada: 0:00:00
# [██████████████████████████████████████████████████]
#
# == RESUMEN FINAL 2015 ==
# yellow 2015-01: 12741035 filas
# yellow 2015-02: 12442394 filas
# yellow 2015-03: 13342951 filas
# yellow 2015-04: 13063758 filas
# yellow 2015-05: 13157677 filas
# yellow 2015-06: 12324936 filas
# yellow 2015-07: 11559666 filas
# yellow 2015-08: 11123123 filas
# yellow 2015-09: 11218122 filas
# yellow 2015-10: 12307333 filas
# yellow 2015-11: 11305240 filas
# yellow 2015-12: 11452996 filas
# green 2015-01: 1508493 filas
# green 2015-02: 1574830 filas
# green 2015-03: 1722574 filas
# green 2015-04: 1664394 filas
# green 2015-05: 1786848 filas
# green 2015-06: 1638868 filas
# green 2015-07: 1541671 filas
# green 2015-08: 1532343 filas
# green 2015-09: 1494927 filas
# green 2015-10: 1630536 filas
# green 2015-11: 1529984 filas
# green 2015-12: 1608297 filas
#
# Duración total: 1:30:30

# %%
import time
from datetime import timedelta

start = time.time()
cnt = ingest_month("yellow", 2016, 1)
elapsed = time.time() - start
print("Tiempo yellow 2016-01:", timedelta(seconds=int(elapsed)), "filas:", cnt)
# Out:
# [yellow 2016-01] BORRADOS anteriores: 0
# [yellow 2016-01] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2016-01.parquet
# [yellow 2016-01] INSERTADAS: 10905067 filas
# Tiempo yellow 2016-01: 0:02:52 filas: 10905067

# %%
ingest_month("yellow", 2016, 1)
ingest_month("green", 2016, 1)
# Out:
# [yellow 2016-01] BORRADOS anteriores: 10905067
# [yellow 2016-01] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2016-01.parquet
# [yellow 2016-01] INSERTADAS: 10905067 filas
# [green 2016-01] BORRADOS anteriores: 0
# [green 2016-01] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2016-01.parquet
# [green 2016-01] INSERTADAS: 1445292 filas
# 1445292

# %%
import time
from datetime import timedelta

services = ["yellow", "green"]
years = list(range(2016, 2026))  # 2016–2024
months = list(range(1, 13))

jobs = []
for y in years:
    for svc in services:
        for m in months:
            jobs.append((svc, y, m))

total_jobs = len(jobs)
done = 0
start_global = time.time()
resumen = []

print(f"== Iniciando ingesta años {years[0]}–{years[-1]} ==")

for svc, y, m in jobs:
    print("\n" + "="*70)
    print(f">>> Ingestando {svc.upper()} {y}-{m:02d}")

    start = time.time()
    cnt = ingest_month(svc, y, m)
    elapsed = time.time() - start

    done += 1
    global_elapsed = time.time() - start_global
    avg_per_job = global_elapsed / done
    remaining_jobs = total_jobs - done
    eta = remaining_jobs * avg_per_job

    print(f"{svc} {y}-{m:02d}: {cnt} filas")
    print(f"Tiempo: {timedelta(seconds=int(elapsed))}")
    print(f"Progreso: {done}/{total_jobs}")
    print(f"ETA aproximada: {timedelta(seconds=int(eta))}")

    # Barra de progreso
    bar_length = 50
    filled = int(bar_length * done / total_jobs)
    bar = "█" * filled + "-" * (bar_length - filled)
    print(f"[{bar}]")

    resumen.append((svc, y, m, cnt))

print("\n== RESUMEN FINAL MULTIANUAL ==")
for svc, y, m, cnt in resumen:
    print(f"{svc} {y}-{m:02d}: {cnt} filas")

print("\nDuración total:", timedelta(seconds=int(time.time() - start_global)))
# Out:
# == Iniciando ingesta años 2016–2025 ==
#
# ======================================================================
# >>> Ingestando YELLOW 2016-01
# [yellow 2016-01] BORRADOS anteriores: 10905067
# [yellow 2016-01] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2016-01.parquet
# [yellow 2016-01] INSERTADAS: 10905067 filas
# yellow 2016-01: 10905067 filas
# Tiempo: 0:04:47
# Progreso: 1/240
# ETA aproximada: 19:06:44
# [--------------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2016-02
# [yellow 2016-02] BORRADOS anteriores: 11375412
# [yellow 2016-02] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2016-02.parquet
# [yellow 2016-02] INSERTADAS: 11375412 filas
# yellow 2016-02: 11375412 filas
# Tiempo: 0:04:58
# Progreso: 2/240
# ETA aproximada: 19:23:14
# [--------------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2016-03
# [yellow 2016-03] BORRADOS anteriores: 12203824
# [yellow 2016-03] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2016-03.parquet
# [yellow 2016-03] INSERTADAS: 12203824 filas
# yellow 2016-03: 12203824 filas
# Tiempo: 0:05:08
# Progreso: 3/240
# ETA aproximada: 19:38:37
# [--------------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2016-04
# [yellow 2016-04] BORRADOS anteriores: 11927996
# [yellow 2016-04] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2016-04.parquet
# [yellow 2016-04] INSERTADAS: 11927996 filas
# yellow 2016-04: 11927996 filas
# Tiempo: 0:05:06
# Progreso: 4/240
# ETA aproximada: 19:41:33
# [--------------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2016-05
# [yellow 2016-05] BORRADOS anteriores: 11832049
# [yellow 2016-05] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2016-05.parquet
# [yellow 2016-05] INSERTADAS: 11832049 filas
# yellow 2016-05: 11832049 filas
# Tiempo: 0:05:09
# Progreso: 5/240
# ETA aproximada: 19:43:26
# [█-------------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2016-06
# [yellow 2016-06] BORRADOS anteriores: 11131645
# [yellow 2016-06] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2016-06.parquet
# [yellow 2016-06] INSERTADAS: 11131645 filas
# yellow 2016-06: 11131645 filas
# Tiempo: 0:05:00
# Progreso: 6/240
# ETA aproximada: 19:37:23
# [█-------------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2016-07
# [yellow 2016-07] BORRADOS anteriores: 10294080
# [yellow 2016-07] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2016-07.parquet
# [yellow 2016-07] INSERTADAS: 10294080 filas
# yellow 2016-07: 10294080 filas
# Tiempo: 0:04:46
# Progreso: 7/240
# ETA aproximada: 19:23:39
# [█-------------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2016-08
# [yellow 2016-08] BORRADOS anteriores: 9942263
# [yellow 2016-08] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2016-08.parquet
# [yellow 2016-08] INSERTADAS: 9942263 filas
# yellow 2016-08: 9942263 filas
# Tiempo: 0:04:42
# Progreso: 8/240
# ETA aproximada: 19:10:12
# [█-------------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2016-09
# [yellow 2016-09] BORRADOS anteriores: 10116018
# [yellow 2016-09] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2016-09.parquet
# [yellow 2016-09] INSERTADAS: 10116018 filas
# yellow 2016-09: 10116018 filas
# Tiempo: 0:04:44
# Progreso: 9/240
# ETA aproximada: 18:59:31
# [█-------------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2016-10
# [yellow 2016-10] BORRADOS anteriores: 10854626
# [yellow 2016-10] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2016-10.parquet
# [yellow 2016-10] INSERTADAS: 10854626 filas
# yellow 2016-10: 10854626 filas
# Tiempo: 0:04:55
# Progreso: 10/240
# ETA aproximada: 18:54:34
# [██------------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2016-11
# [yellow 2016-11] BORRADOS anteriores: 10102128
# [yellow 2016-11] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2016-11.parquet
# [yellow 2016-11] INSERTADAS: 10102128 filas
# yellow 2016-11: 10102128 filas
# Tiempo: 0:04:45
# Progreso: 11/240
# ETA aproximada: 18:46:08
# [██------------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2016-12
# [yellow 2016-12] BORRADOS anteriores: 10446697
# [yellow 2016-12] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2016-12.parquet
# [yellow 2016-12] INSERTADAS: 10446697 filas
# yellow 2016-12: 10446697 filas
# Tiempo: 0:04:51
# Progreso: 12/240
# ETA aproximada: 18:40:00
# [██------------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2016-01
# [green 2016-01] BORRADOS anteriores: 1445292
# [green 2016-01] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2016-01.parquet
# [green 2016-01] INSERTADAS: 1445292 filas
# green 2016-01: 1445292 filas
# Tiempo: 0:00:34
# Progreso: 13/240
# ETA aproximada: 17:19:22
# [██------------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2016-02
# [green 2016-02] BORRADOS anteriores: 1510722
# [green 2016-02] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2016-02.parquet
# [green 2016-02] INSERTADAS: 1510722 filas
# green 2016-02: 1510722 filas
# Tiempo: 0:00:37
# Progreso: 14/240
# ETA aproximada: 16:10:53
# [██------------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2016-03
# [green 2016-03] BORRADOS anteriores: 1576393
# [green 2016-03] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2016-03.parquet
# [green 2016-03] INSERTADAS: 1576393 filas
# green 2016-03: 1576393 filas
# Tiempo: 0:00:38
# Progreso: 15/240
# ETA aproximada: 15:11:44
# [███-----------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2016-04
# [green 2016-04] BORRADOS anteriores: 1543926
# [green 2016-04] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2016-04.parquet
# [green 2016-04] INSERTADAS: 1543926 filas
# green 2016-04: 1543926 filas
# Tiempo: 0:00:38
# Progreso: 16/240
# ETA aproximada: 14:19:52
# [███-----------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2016-05
# [green 2016-05] BORRADOS anteriores: 1536979
# [green 2016-05] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2016-05.parquet
# [green 2016-05] INSERTADAS: 1536979 filas
# green 2016-05: 1536979 filas
# Tiempo: 0:00:38
# Progreso: 17/240
# ETA aproximada: 13:34:06
# [███-----------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2016-06
# [green 2016-06] BORRADOS anteriores: 1404727
# [green 2016-06] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2016-06.parquet
# [green 2016-06] INSERTADAS: 1404727 filas
# green 2016-06: 1404727 filas
# Tiempo: 0:00:35
# Progreso: 18/240
# ETA aproximada: 12:52:48
# [███-----------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2016-07
# [green 2016-07] BORRADOS anteriores: 1332510
# [green 2016-07] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2016-07.parquet
# [green 2016-07] INSERTADAS: 1332510 filas
# green 2016-07: 1332510 filas
# Tiempo: 0:00:33
# Progreso: 19/240
# ETA aproximada: 12:15:21
# [███-----------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2016-08
# [green 2016-08] BORRADOS anteriores: 1247675
# [green 2016-08] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2016-08.parquet
# [green 2016-08] INSERTADAS: 1247675 filas
# green 2016-08: 1247675 filas
# Tiempo: 0:00:31
# Progreso: 20/240
# ETA aproximada: 11:41:07
# [████----------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2016-09
# [green 2016-09] BORRADOS anteriores: 1162373
# [green 2016-09] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2016-09.parquet
# [green 2016-09] INSERTADAS: 1162373 filas
# green 2016-09: 1162373 filas
# Tiempo: 0:00:29
# Progreso: 21/240
# ETA aproximada: 11:09:53
# [████----------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2016-10
# [green 2016-10] BORRADOS anteriores: 1252572
# [green 2016-10] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2016-10.parquet
# [green 2016-10] INSERTADAS: 1252572 filas
# green 2016-10: 1252572 filas
# Tiempo: 0:00:32
# Progreso: 22/240
# ETA aproximada: 10:41:57
# [████----------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2016-11
# [green 2016-11] BORRADOS anteriores: 1148214
# [green 2016-11] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2016-11.parquet
# [green 2016-11] INSERTADAS: 1148214 filas
# green 2016-11: 1148214 filas
# Tiempo: 0:00:32
# Progreso: 23/240
# ETA aproximada: 10:16:16
# [████----------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2016-12
# [green 2016-12] BORRADOS anteriores: 1224158
# [green 2016-12] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2016-12.parquet
# [green 2016-12] INSERTADAS: 1224158 filas
# green 2016-12: 1224158 filas
# Tiempo: 0:00:35
# Progreso: 24/240
# ETA aproximada: 9:53:16
# [█████---------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2017-01
# [yellow 2017-01] BORRADOS anteriores: 9710820
# [yellow 2017-01] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2017-01.parquet
# [yellow 2017-01] INSERTADAS: 9710820 filas
# yellow 2017-01: 9710820 filas
# Tiempo: 0:04:48
# Progreso: 25/240
# ETA aproximada: 10:08:18
# [█████---------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2017-02
# [yellow 2017-02] BORRADOS anteriores: 9169775
# [yellow 2017-02] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2017-02.parquet
# [yellow 2017-02] INSERTADAS: 9169775 filas
# yellow 2017-02: 9169775 filas
# Tiempo: 0:04:34
# Progreso: 26/240
# ETA aproximada: 10:19:52
# [█████---------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2017-03
# [yellow 2017-03] BORRADOS anteriores: 10295441
# [yellow 2017-03] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2017-03.parquet
# [yellow 2017-03] INSERTADAS: 10295441 filas
# yellow 2017-03: 10295441 filas
# Tiempo: 0:04:48
# Progreso: 27/240
# ETA aproximada: 10:32:05
# [█████---------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2017-04
# [yellow 2017-04] BORRADOS anteriores: 10047135
# [yellow 2017-04] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2017-04.parquet
# [yellow 2017-04] INSERTADAS: 10047135 filas
# yellow 2017-04: 10047135 filas
# Tiempo: 0:04:42
# Progreso: 28/240
# ETA aproximada: 10:42:16
# [█████---------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2017-05
# [yellow 2017-05] BORRADOS anteriores: 10102127
# [yellow 2017-05] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2017-05.parquet
# [yellow 2017-05] INSERTADAS: 10102127 filas
# yellow 2017-05: 10102127 filas
# Tiempo: 0:04:40
# Progreso: 29/240
# ETA aproximada: 10:51:15
# [██████--------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2017-06
# [yellow 2017-06] BORRADOS anteriores: 9656993
# [yellow 2017-06] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2017-06.parquet
# [yellow 2017-06] INSERTADAS: 9656993 filas
# yellow 2017-06: 9656993 filas
# Tiempo: 0:04:33
# Progreso: 30/240
# ETA aproximada: 10:58:29
# [██████--------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2017-07
# [yellow 2017-07] BORRADOS anteriores: 8588486
# [yellow 2017-07] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2017-07.parquet
# [yellow 2017-07] INSERTADAS: 8588486 filas
# yellow 2017-07: 8588486 filas
# Tiempo: 0:04:19
# Progreso: 31/240
# ETA aproximada: 11:03:21
# [██████--------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2017-08
# [yellow 2017-08] BORRADOS anteriores: 8422153
# [yellow 2017-08] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2017-08.parquet
# [yellow 2017-08] INSERTADAS: 8422153 filas
# yellow 2017-08: 8422153 filas
# Tiempo: 0:04:16
# Progreso: 32/240
# ETA aproximada: 11:07:20
# [██████--------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2017-09
# [yellow 2017-09] BORRADOS anteriores: 8945421
# [yellow 2017-09] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2017-09.parquet
# [yellow 2017-09] INSERTADAS: 8945421 filas
# yellow 2017-09: 8945421 filas
# Tiempo: 0:04:30
# Progreso: 33/240
# ETA aproximada: 11:12:19
# [██████--------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2017-10
# [yellow 2017-10] BORRADOS anteriores: 9768672
# [yellow 2017-10] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2017-10.parquet
# [yellow 2017-10] INSERTADAS: 9768672 filas
# yellow 2017-10: 9768672 filas
# Tiempo: 0:04:50
# Progreso: 34/240
# ETA aproximada: 11:18:44
# [███████-------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2017-11
# [yellow 2017-11] BORRADOS anteriores: 9284803
# [yellow 2017-11] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2017-11.parquet
# [yellow 2017-11] INSERTADAS: 9284803 filas
# yellow 2017-11: 9284803 filas
# Tiempo: 0:04:42
# Progreso: 35/240
# ETA aproximada: 11:23:46
# [███████-------------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2017-12
# [yellow 2017-12] BORRADOS anteriores: 9508501
# [yellow 2017-12] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2017-12.parquet
# [yellow 2017-12] INSERTADAS: 9508501 filas
# yellow 2017-12: 9508501 filas
# Tiempo: 0:04:40
# Progreso: 36/240
# ETA aproximada: 11:28:03
# [███████-------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2017-01
# [green 2017-01] BORRADOS anteriores: 1069565
# [green 2017-01] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2017-01.parquet
# [green 2017-01] INSERTADAS: 1069565 filas
# green 2017-01: 1069565 filas
# Tiempo: 0:00:31
# Progreso: 37/240
# ETA aproximada: 11:09:02
# [███████-------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2017-02
# [green 2017-02] BORRADOS anteriores: 1022313
# [green 2017-02] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2017-02.parquet
# [green 2017-02] INSERTADAS: 1022313 filas
# green 2017-02: 1022313 filas
# Tiempo: 0:00:29
# Progreso: 38/240
# ETA aproximada: 10:50:50
# [███████-------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2017-03
# [green 2017-03] BORRADOS anteriores: 1157827
# [green 2017-03] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2017-03.parquet
# [green 2017-03] INSERTADAS: 1157827 filas
# green 2017-03: 1157827 filas
# Tiempo: 0:00:32
# Progreso: 39/240
# ETA aproximada: 10:33:46
# [████████------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2017-04
# [green 2017-04] BORRADOS anteriores: 1080844
# [green 2017-04] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2017-04.parquet
# [green 2017-04] INSERTADAS: 1080844 filas
# green 2017-04: 1080844 filas
# Tiempo: 0:00:30
# Progreso: 40/240
# ETA aproximada: 10:17:25
# [████████------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2017-05
# [green 2017-05] BORRADOS anteriores: 1059463
# [green 2017-05] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2017-05.parquet
# [green 2017-05] INSERTADAS: 1059463 filas
# green 2017-05: 1059463 filas
# Tiempo: 0:00:30
# Progreso: 41/240
# ETA aproximada: 10:01:49
# [████████------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2017-06
# [green 2017-06] BORRADOS anteriores: 976467
# [green 2017-06] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2017-06.parquet
# [green 2017-06] INSERTADAS: 976467 filas
# green 2017-06: 976467 filas
# Tiempo: 0:00:29
# Progreso: 42/240
# ETA aproximada: 9:46:49
# [████████------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2017-07
# [green 2017-07] BORRADOS anteriores: 914783
# [green 2017-07] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2017-07.parquet
# [green 2017-07] INSERTADAS: 914783 filas
# green 2017-07: 914783 filas
# Tiempo: 0:00:27
# Progreso: 43/240
# ETA aproximada: 9:32:23
# [████████------------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2017-08
# [green 2017-08] BORRADOS anteriores: 867407
# [green 2017-08] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2017-08.parquet
# [green 2017-08] INSERTADAS: 867407 filas
# green 2017-08: 867407 filas
# Tiempo: 0:00:26
# Progreso: 44/240
# ETA aproximada: 9:18:30
# [█████████-----------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2017-09
# [green 2017-09] BORRADOS anteriores: 882464
# [green 2017-09] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2017-09.parquet
# [green 2017-09] INSERTADAS: 882464 filas
# green 2017-09: 882464 filas
# Tiempo: 0:00:26
# Progreso: 45/240
# ETA aproximada: 9:05:13
# [█████████-----------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2017-10
# [green 2017-10] BORRADOS anteriores: 925737
# [green 2017-10] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2017-10.parquet
# [green 2017-10] INSERTADAS: 925737 filas
# green 2017-10: 925737 filas
# Tiempo: 0:00:27
# Progreso: 46/240
# ETA aproximada: 8:52:33
# [█████████-----------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2017-11
# [green 2017-11] BORRADOS anteriores: 874173
# [green 2017-11] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2017-11.parquet
# [green 2017-11] INSERTADAS: 874173 filas
# green 2017-11: 874173 filas
# Tiempo: 0:00:26
# Progreso: 47/240
# ETA aproximada: 8:40:19
# [█████████-----------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2017-12
# [green 2017-12] BORRADOS anteriores: 906016
# [green 2017-12] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2017-12.parquet
# [green 2017-12] INSERTADAS: 906016 filas
# green 2017-12: 906016 filas
# Tiempo: 0:00:27
# Progreso: 48/240
# ETA aproximada: 8:28:39
# [██████████----------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2018-01
# [yellow 2018-01] BORRADOS anteriores: 8760687
# [yellow 2018-01] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2018-01.parquet
# [yellow 2018-01] INSERTADAS: 8760687 filas
# yellow 2018-01: 8760687 filas
# Tiempo: 0:04:30
# Progreso: 49/240
# ETA aproximada: 8:33:16
# [██████████----------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2018-02
# [yellow 2018-02] BORRADOS anteriores: 8492819
# [yellow 2018-02] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2018-02.parquet
# [yellow 2018-02] INSERTADAS: 8492819 filas
# yellow 2018-02: 8492819 filas
# Tiempo: 0:04:22
# Progreso: 50/240
# ETA aproximada: 8:37:01
# [██████████----------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2018-03
# [yellow 2018-03] BORRADOS anteriores: 9431289
# [yellow 2018-03] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2018-03.parquet
# [yellow 2018-03] INSERTADAS: 9431289 filas
# yellow 2018-03: 9431289 filas
# Tiempo: 0:04:38
# Progreso: 51/240
# ETA aproximada: 8:41:24
# [██████████----------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2018-04
# [yellow 2018-04] BORRADOS anteriores: 9306216
# [yellow 2018-04] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2018-04.parquet
# [yellow 2018-04] INSERTADAS: 9306216 filas
# yellow 2018-04: 9306216 filas
# Tiempo: 0:04:34
# Progreso: 52/240
# ETA aproximada: 8:45:12
# [██████████----------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2018-05
# [yellow 2018-05] BORRADOS anteriores: 9224788
# [yellow 2018-05] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2018-05.parquet
# [yellow 2018-05] INSERTADAS: 9224788 filas
# yellow 2018-05: 9224788 filas
# Tiempo: 0:04:35
# Progreso: 53/240
# ETA aproximada: 8:48:45
# [███████████---------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2018-06
# [yellow 2018-06] BORRADOS anteriores: 8714667
# [yellow 2018-06] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2018-06.parquet
# [yellow 2018-06] INSERTADAS: 8714667 filas
# yellow 2018-06: 8714667 filas
# Tiempo: 0:04:23
# Progreso: 54/240
# ETA aproximada: 8:51:19
# [███████████---------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2018-07
# [yellow 2018-07] BORRADOS anteriores: 7851143
# [yellow 2018-07] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2018-07.parquet
# [yellow 2018-07] INSERTADAS: 7851143 filas
# yellow 2018-07: 7851143 filas
# Tiempo: 0:04:14
# Progreso: 55/240
# ETA aproximada: 8:53:08
# [███████████---------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2018-08
# [yellow 2018-08] BORRADOS anteriores: 7855040
# [yellow 2018-08] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2018-08.parquet
# [yellow 2018-08] INSERTADAS: 7855040 filas
# yellow 2018-08: 7855040 filas
# Tiempo: 0:04:14
# Progreso: 56/240
# ETA aproximada: 8:54:41
# [███████████---------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2018-09
# [yellow 2018-09] BORRADOS anteriores: 8049094
# [yellow 2018-09] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2018-09.parquet
# [yellow 2018-09] INSERTADAS: 8049094 filas
# yellow 2018-09: 8049094 filas
# Tiempo: 0:04:19
# Progreso: 57/240
# ETA aproximada: 8:56:19
# [███████████---------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2018-10
# [yellow 2018-10] BORRADOS anteriores: 8834520
# [yellow 2018-10] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2018-10.parquet
# [yellow 2018-10] INSERTADAS: 8834520 filas
# yellow 2018-10: 8834520 filas
# Tiempo: 0:04:26
# Progreso: 58/240
# ETA aproximada: 8:58:07
# [████████████--------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2018-11
# [yellow 2018-11] BORRADOS anteriores: 8155449
# [yellow 2018-11] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2018-11.parquet
# [yellow 2018-11] INSERTADAS: 8155449 filas
# yellow 2018-11: 8155449 filas
# Tiempo: 0:04:21
# Progreso: 59/240
# ETA aproximada: 8:59:26
# [████████████--------------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2018-12
# [yellow 2018-12] BORRADOS anteriores: 8195675
# [yellow 2018-12] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2018-12.parquet
# [yellow 2018-12] INSERTADAS: 8195675 filas
# yellow 2018-12: 8195675 filas
# Tiempo: 0:04:22
# Progreso: 60/240
# ETA aproximada: 9:00:37
# [████████████--------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2018-01
# [green 2018-01] BORRADOS anteriores: 792744
# [green 2018-01] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2018-01.parquet
# [green 2018-01] INSERTADAS: 792744 filas
# green 2018-01: 792744 filas
# Tiempo: 0:00:25
# Progreso: 61/240
# ETA aproximada: 8:50:03
# [████████████--------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2018-02
# [green 2018-02] BORRADOS anteriores: 769197
# [green 2018-02] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2018-02.parquet
# [green 2018-02] INSERTADAS: 769197 filas
# green 2018-02: 769197 filas
# Tiempo: 0:00:25
# Progreso: 62/240
# ETA aproximada: 8:39:47
# [████████████--------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2018-03
# [green 2018-03] BORRADOS anteriores: 836246
# [green 2018-03] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2018-03.parquet
# [green 2018-03] INSERTADAS: 836246 filas
# green 2018-03: 836246 filas
# Tiempo: 0:00:25
# Progreso: 63/240
# ETA aproximada: 8:29:50
# [█████████████-------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2018-04
# [green 2018-04] BORRADOS anteriores: 799383
# [green 2018-04] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2018-04.parquet
# [green 2018-04] INSERTADAS: 799383 filas
# green 2018-04: 799383 filas
# Tiempo: 0:00:25
# Progreso: 64/240
# ETA aproximada: 8:20:11
# [█████████████-------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2018-05
# [green 2018-05] BORRADOS anteriores: 796552
# [green 2018-05] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2018-05.parquet
# [green 2018-05] INSERTADAS: 796552 filas
# green 2018-05: 796552 filas
# Tiempo: 0:00:25
# Progreso: 65/240
# ETA aproximada: 8:10:49
# [█████████████-------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2018-06
# [green 2018-06] BORRADOS anteriores: 738546
# [green 2018-06] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2018-06.parquet
# [green 2018-06] INSERTADAS: 738546 filas
# green 2018-06: 738546 filas
# Tiempo: 0:00:25
# Progreso: 66/240
# ETA aproximada: 8:01:44
# [█████████████-------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2018-07
# [green 2018-07] BORRADOS anteriores: 684374
# [green 2018-07] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2018-07.parquet
# [green 2018-07] INSERTADAS: 684374 filas
# green 2018-07: 684374 filas
# Tiempo: 0:00:23
# Progreso: 67/240
# ETA aproximada: 7:52:50
# [█████████████-------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2018-08
# [green 2018-08] BORRADOS anteriores: 675815
# [green 2018-08] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2018-08.parquet
# [green 2018-08] INSERTADAS: 675815 filas
# green 2018-08: 675815 filas
# Tiempo: 0:00:23
# Progreso: 68/240
# ETA aproximada: 7:44:11
# [██████████████------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2018-09
# [green 2018-09] BORRADOS anteriores: 682032
# [green 2018-09] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2018-09.parquet
# [green 2018-09] INSERTADAS: 682032 filas
# green 2018-09: 682032 filas
# Tiempo: 0:00:23
# Progreso: 69/240
# ETA aproximada: 7:35:47
# [██████████████------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2018-10
# [green 2018-10] BORRADOS anteriores: 731888
# [green 2018-10] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2018-10.parquet
# [green 2018-10] INSERTADAS: 731888 filas
# green 2018-10: 731888 filas
# Tiempo: 0:00:24
# Progreso: 70/240
# ETA aproximada: 7:27:38
# [██████████████------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2018-11
# [green 2018-11] BORRADOS anteriores: 673287
# [green 2018-11] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2018-11.parquet
# [green 2018-11] INSERTADAS: 673287 filas
# green 2018-11: 673287 filas
# Tiempo: 0:00:23
# Progreso: 71/240
# ETA aproximada: 7:19:40
# [██████████████------------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2018-12
# [green 2018-12] BORRADOS anteriores: 719654
# [green 2018-12] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2018-12.parquet
# [green 2018-12] INSERTADAS: 719654 filas
# green 2018-12: 719654 filas
# Tiempo: 0:00:23
# Progreso: 72/240
# ETA aproximada: 7:11:55
# [███████████████-----------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2019-01
# [yellow 2019-01] BORRADOS anteriores: 7696617
# [yellow 2019-01] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2019-01.parquet
# [yellow 2019-01] INSERTADAS: 7696617 filas
# yellow 2019-01: 7696617 filas
# Tiempo: 0:04:13
# Progreso: 73/240
# ETA aproximada: 7:13:07
# [███████████████-----------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2019-02
# [yellow 2019-02] BORRADOS anteriores: 7049370
# [yellow 2019-02] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2019-02.parquet
# [yellow 2019-02] INSERTADAS: 7049370 filas
# yellow 2019-02: 7049370 filas
# Tiempo: 0:04:11
# Progreso: 74/240
# ETA aproximada: 7:14:06
# [███████████████-----------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2019-03
# [yellow 2019-03] BORRADOS anteriores: 7866620
# [yellow 2019-03] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2019-03.parquet
# [yellow 2019-03] INSERTADAS: 7866620 filas
# yellow 2019-03: 7866620 filas
# Tiempo: 0:04:22
# Progreso: 75/240
# ETA aproximada: 7:15:21
# [███████████████-----------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2019-04
# [yellow 2019-04] BORRADOS anteriores: 7475949
# [yellow 2019-04] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2019-04.parquet
# [yellow 2019-04] INSERTADAS: 7475949 filas
# yellow 2019-04: 7475949 filas
# Tiempo: 0:04:18
# Progreso: 76/240
# ETA aproximada: 7:16:18
# [███████████████-----------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2019-05
# [yellow 2019-05] BORRADOS anteriores: 7598445
# [yellow 2019-05] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2019-05.parquet
# [yellow 2019-05] INSERTADAS: 7598445 filas
# yellow 2019-05: 7598445 filas
# Tiempo: 0:04:16
# Progreso: 77/240
# ETA aproximada: 7:17:05
# [████████████████----------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2019-06
# [yellow 2019-06] BORRADOS anteriores: 6971560
# [yellow 2019-06] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2019-06.parquet
# [yellow 2019-06] INSERTADAS: 6971560 filas
# yellow 2019-06: 6971560 filas
# Tiempo: 0:04:08
# Progreso: 78/240
# ETA aproximada: 7:17:26
# [████████████████----------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2019-07
# [yellow 2019-07] BORRADOS anteriores: 6310419
# [yellow 2019-07] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2019-07.parquet
# [yellow 2019-07] INSERTADAS: 6310419 filas
# yellow 2019-07: 6310419 filas
# Tiempo: 0:03:47
# Progreso: 79/240
# ETA aproximada: 7:16:58
# [████████████████----------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2019-08
# [yellow 2019-08] BORRADOS anteriores: 6073357
# [yellow 2019-08] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2019-08.parquet
# [yellow 2019-08] INSERTADAS: 6073357 filas
# yellow 2019-08: 6073357 filas
# Tiempo: 0:03:42
# Progreso: 80/240
# ETA aproximada: 7:16:14
# [████████████████----------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2019-09
# [yellow 2019-09] BORRADOS anteriores: 6567788
# [yellow 2019-09] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2019-09.parquet
# [yellow 2019-09] INSERTADAS: 6567788 filas
# yellow 2019-09: 6567788 filas
# Tiempo: 0:03:45
# Progreso: 81/240
# ETA aproximada: 7:15:33
# [████████████████----------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2019-10
# [yellow 2019-10] BORRADOS anteriores: 7213891
# [yellow 2019-10] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2019-10.parquet
# [yellow 2019-10] INSERTADAS: 7213891 filas
# yellow 2019-10: 7213891 filas
# Tiempo: 0:04:00
# Progreso: 82/240
# ETA aproximada: 7:15:15
# [█████████████████---------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2019-11
# [yellow 2019-11] BORRADOS anteriores: 6878111
# [yellow 2019-11] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2019-11.parquet
# [yellow 2019-11] INSERTADAS: 6878111 filas
# yellow 2019-11: 6878111 filas
# Tiempo: 0:03:57
# Progreso: 83/240
# ETA aproximada: 7:14:46
# [█████████████████---------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2019-12
# [yellow 2019-12] BORRADOS anteriores: 6896317
# [yellow 2019-12] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2019-12.parquet
# [yellow 2019-12] INSERTADAS: 6896317 filas
# yellow 2019-12: 6896317 filas
# Tiempo: 0:04:00
# Progreso: 84/240
# ETA aproximada: 7:14:17
# [█████████████████---------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2019-01
# [green 2019-01] BORRADOS anteriores: 672105
# [green 2019-01] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2019-01.parquet
# [green 2019-01] INSERTADAS: 672105 filas
# green 2019-01: 672105 filas
# Tiempo: 0:00:33
# Progreso: 85/240
# ETA aproximada: 7:07:27
# [█████████████████---------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2019-02
# [green 2019-02] BORRADOS anteriores: 615594
# [green 2019-02] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2019-02.parquet
# [green 2019-02] INSERTADAS: 615594 filas
# green 2019-02: 615594 filas
# Tiempo: 0:00:22
# Progreso: 86/240
# ETA aproximada: 7:00:25
# [█████████████████---------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2019-03
# [green 2019-03] BORRADOS anteriores: 643063
# [green 2019-03] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2019-03.parquet
# [green 2019-03] INSERTADAS: 643063 filas
# green 2019-03: 643063 filas
# Tiempo: 0:00:22
# Progreso: 87/240
# ETA aproximada: 6:53:33
# [██████████████████--------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2019-04
# [green 2019-04] BORRADOS anteriores: 567852
# [green 2019-04] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2019-04.parquet
# [green 2019-04] INSERTADAS: 567852 filas
# green 2019-04: 567852 filas
# Tiempo: 0:00:21
# Progreso: 88/240
# ETA aproximada: 6:46:48
# [██████████████████--------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2019-05
# [green 2019-05] BORRADOS anteriores: 545452
# [green 2019-05] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2019-05.parquet
# [green 2019-05] INSERTADAS: 545452 filas
# green 2019-05: 545452 filas
# Tiempo: 0:00:20
# Progreso: 89/240
# ETA aproximada: 6:40:10
# [██████████████████--------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2019-06
# [green 2019-06] BORRADOS anteriores: 506238
# [green 2019-06] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2019-06.parquet
# [green 2019-06] INSERTADAS: 506238 filas
# green 2019-06: 506238 filas
# Tiempo: 0:00:19
# Progreso: 90/240
# ETA aproximada: 6:33:39
# [██████████████████--------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2019-07
# [green 2019-07] BORRADOS anteriores: 470743
# [green 2019-07] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2019-07.parquet
# [green 2019-07] INSERTADAS: 470743 filas
# green 2019-07: 470743 filas
# Tiempo: 0:00:19
# Progreso: 91/240
# ETA aproximada: 6:27:16
# [██████████████████--------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2019-08
# [green 2019-08] BORRADOS anteriores: 449695
# [green 2019-08] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2019-08.parquet
# [green 2019-08] INSERTADAS: 449695 filas
# green 2019-08: 449695 filas
# Tiempo: 0:00:19
# Progreso: 92/240
# ETA aproximada: 6:21:01
# [███████████████████-------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2019-09
# [green 2019-09] BORRADOS anteriores: 449063
# [green 2019-09] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2019-09.parquet
# [green 2019-09] INSERTADAS: 449063 filas
# green 2019-09: 449063 filas
# Tiempo: 0:00:19
# Progreso: 93/240
# ETA aproximada: 6:14:53
# [███████████████████-------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2019-10
# [green 2019-10] BORRADOS anteriores: 476386
# [green 2019-10] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2019-10.parquet
# [green 2019-10] INSERTADAS: 476386 filas
# green 2019-10: 476386 filas
# Tiempo: 0:00:20
# Progreso: 94/240
# ETA aproximada: 6:08:53
# [███████████████████-------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2019-11
# [green 2019-11] BORRADOS anteriores: 449500
# [green 2019-11] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2019-11.parquet
# [green 2019-11] INSERTADAS: 449500 filas
# green 2019-11: 449500 filas
# Tiempo: 0:00:19
# Progreso: 95/240
# ETA aproximada: 6:03:00
# [███████████████████-------------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2019-12
# [green 2019-12] BORRADOS anteriores: 455294
# [green 2019-12] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2019-12.parquet
# [green 2019-12] INSERTADAS: 455294 filas
# green 2019-12: 455294 filas
# Tiempo: 0:00:19
# Progreso: 96/240
# ETA aproximada: 5:57:13
# [████████████████████------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2020-01
# [yellow 2020-01] BORRADOS anteriores: 6405008
# [yellow 2020-01] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2020-01.parquet
# [yellow 2020-01] INSERTADAS: 6405008 filas
# yellow 2020-01: 6405008 filas
# Tiempo: 0:03:56
# Progreso: 97/240
# ETA aproximada: 5:56:54
# [████████████████████------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2020-02
# [yellow 2020-02] BORRADOS anteriores: 6299367
# [yellow 2020-02] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2020-02.parquet
# [yellow 2020-02] INSERTADAS: 6299367 filas
# yellow 2020-02: 6299367 filas
# Tiempo: 0:03:49
# Progreso: 98/240
# ETA aproximada: 5:56:19
# [████████████████████------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2020-03
# [yellow 2020-03] BORRADOS anteriores: 3007687
# [yellow 2020-03] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2020-03.parquet
# [yellow 2020-03] INSERTADAS: 3007687 filas
# yellow 2020-03: 3007687 filas
# Tiempo: 0:02:59
# Progreso: 99/240
# ETA aproximada: 5:54:30
# [████████████████████------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2020-04
# [yellow 2020-04] BORRADOS anteriores: 238073
# [yellow 2020-04] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2020-04.parquet
# [yellow 2020-04] INSERTADAS: 238073 filas
# yellow 2020-04: 238073 filas
# Tiempo: 0:02:12
# Progreso: 100/240
# ETA aproximada: 5:51:33
# [████████████████████------------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2020-05
# [yellow 2020-05] BORRADOS anteriores: 348415
# [yellow 2020-05] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2020-05.parquet
# [yellow 2020-05] INSERTADAS: 348415 filas
# yellow 2020-05: 348415 filas
# Tiempo: 0:02:11
# Progreso: 101/240
# ETA aproximada: 5:48:37
# [█████████████████████-----------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2020-06
# [yellow 2020-06] BORRADOS anteriores: 549797
# [yellow 2020-06] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2020-06.parquet
# [yellow 2020-06] INSERTADAS: 549797 filas
# yellow 2020-06: 549797 filas
# Tiempo: 0:02:12
# Progreso: 102/240
# ETA aproximada: 5:45:41
# [█████████████████████-----------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2020-07
# [yellow 2020-07] BORRADOS anteriores: 800412
# [yellow 2020-07] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2020-07.parquet
# [yellow 2020-07] INSERTADAS: 800412 filas
# yellow 2020-07: 800412 filas
# Tiempo: 0:02:15
# Progreso: 103/240
# ETA aproximada: 5:42:52
# [█████████████████████-----------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2020-08
# [yellow 2020-08] BORRADOS anteriores: 1007286
# [yellow 2020-08] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2020-08.parquet
# [yellow 2020-08] INSERTADAS: 1007286 filas
# yellow 2020-08: 1007286 filas
# Tiempo: 0:02:21
# Progreso: 104/240
# ETA aproximada: 5:40:11
# [█████████████████████-----------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2020-09
# [yellow 2020-09] BORRADOS anteriores: 1341017
# [yellow 2020-09] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2020-09.parquet
# [yellow 2020-09] INSERTADAS: 1341017 filas
# yellow 2020-09: 1341017 filas
# Tiempo: 0:02:26
# Progreso: 105/240
# ETA aproximada: 5:37:36
# [█████████████████████-----------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2020-10
# [yellow 2020-10] BORRADOS anteriores: 1681132
# [yellow 2020-10] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2020-10.parquet
# [yellow 2020-10] INSERTADAS: 1681132 filas
# yellow 2020-10: 1681132 filas
# Tiempo: 0:02:31
# Progreso: 106/240
# ETA aproximada: 5:35:08
# [██████████████████████----------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2020-11
# [yellow 2020-11] BORRADOS anteriores: 1509000
# [yellow 2020-11] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2020-11.parquet
# [yellow 2020-11] INSERTADAS: 1509000 filas
# yellow 2020-11: 1509000 filas
# Tiempo: 0:02:28
# Progreso: 107/240
# ETA aproximada: 5:32:36
# [██████████████████████----------------------------]
#
# ======================================================================
# >>> Ingestando YELLOW 2020-12
# [yellow 2020-12] BORRADOS anteriores: 1461898
# [yellow 2020-12] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2020-12.parquet
# [yellow 2020-12] INSERTADAS: 1461898 filas
# yellow 2020-12: 1461898 filas
# Tiempo: 0:02:28
# Progreso: 108/240
# ETA aproximada: 5:30:04
# [██████████████████████----------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2020-01
# [green 2020-01] BORRADOS anteriores: 447770
# [green 2020-01] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2020-01.parquet
# [green 2020-01] INSERTADAS: 447770 filas
# green 2020-01: 447770 filas
# Tiempo: 0:00:19
# Progreso: 109/240
# ETA aproximada: 5:24:57
# [██████████████████████----------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2020-02
# [green 2020-02] BORRADOS anteriores: 398632
# [green 2020-02] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2020-02.parquet
# [green 2020-02] INSERTADAS: 398632 filas
# green 2020-02: 398632 filas
# Tiempo: 0:00:18
# Progreso: 110/240
# ETA aproximada: 5:19:54
# [██████████████████████----------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2020-03
# [green 2020-03] BORRADOS anteriores: 223496
# [green 2020-03] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2020-03.parquet
# [green 2020-03] INSERTADAS: 223496 filas
# green 2020-03: 223496 filas
# Tiempo: 0:00:15
# Progreso: 111/240
# ETA aproximada: 5:14:53
# [███████████████████████---------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2020-04
# [green 2020-04] BORRADOS anteriores: 35644
# [green 2020-04] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2020-04.parquet
# [green 2020-04] INSERTADAS: 35644 filas
# green 2020-04: 35644 filas
# Tiempo: 0:00:12
# Progreso: 112/240
# ETA aproximada: 5:09:54
# [███████████████████████---------------------------]
#
# ======================================================================
# >>> Ingestando GREEN 2020-05
# [green 2020-05] BORRADOS anteriores: 57361
# ...
# [yellow 2023-12] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2023-12.parquet
# [yellow 2023-12] INSERTADAS: 3376567 filas
# yellow 2023-12: 3376567 filas
# Tiempo: 0:02:37
# Progreso: 180/240
# ETA aproximada: 2:07:30
# [█████████████████████████████████████-------------]
#
# ======================================================================
# >>> Ingestando GREEN 2023-01
# [green 2023-01] BORRADOS anteriores: 68211
# [green 2023-01] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2023-01.parquet
# [green 2023-01] INSERTADAS: 68211 filas
# green 2023-01: 68211 filas
# Tiempo: 0:00:13
# Progreso: 181/240
# ETA aproximada: 2:04:46
# [█████████████████████████████████████-------------]
#
# ======================================================================
# >>> Ingestando GREEN 2023-02
# [green 2023-02] BORRADOS anteriores: 64809
# [green 2023-02] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2023-02.parquet
# [green 2023-02] INSERTADAS: 64809 filas
# green 2023-02: 64809 filas
# Tiempo: 0:00:13
# Progreso: 182/240
# ETA aproximada: 2:02:03
# [█████████████████████████████████████-------------]
#
# ======================================================================
# >>> Ingestando GREEN 2023-03
# [green 2023-03] BORRADOS anteriores: 72044
# [green 2023-03] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2023-03.parquet
# [green 2023-03] INSERTADAS: 72044 filas
# green 2023-03: 72044 filas
# Tiempo: 0:00:13
# Progreso: 183/240
# ETA aproximada: 1:59:21
# [██████████████████████████████████████------------]
#
# ======================================================================
# >>> Ingestando GREEN 2023-04
# [green 2023-04] BORRADOS anteriores: 65392
# [green 2023-04] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2023-04.parquet
# [green 2023-04] INSERTADAS: 65392 filas
# green 2023-04: 65392 filas
# Tiempo: 0:00:13
# Progreso: 184/240
# ETA aproximada: 1:56:42
# [██████████████████████████████████████------------]
#
# ======================================================================
# >>> Ingestando GREEN 2023-05
# [green 2023-05] BORRADOS anteriores: 69174
# [green 2023-05] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2023-05.parquet
# [green 2023-05] INSERTADAS: 69174 filas
# green 2023-05: 69174 filas
# Tiempo: 0:00:13
# Progreso: 185/240
# ETA aproximada: 1:54:04
# [██████████████████████████████████████------------]
#
# ======================================================================
# >>> Ingestando GREEN 2023-06
# [green 2023-06] BORRADOS anteriores: 65550
# [green 2023-06] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2023-06.parquet
# [green 2023-06] INSERTADAS: 65550 filas
# green 2023-06: 65550 filas
# Tiempo: 0:00:13
# Progreso: 186/240
# ETA aproximada: 1:51:27
# [██████████████████████████████████████------------]
#
# ======================================================================
# >>> Ingestando GREEN 2023-07
# [green 2023-07] BORRADOS anteriores: 61343
# [green 2023-07] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2023-07.parquet
# [green 2023-07] INSERTADAS: 61343 filas
# green 2023-07: 61343 filas
# Tiempo: 0:00:13
# Progreso: 187/240
# ETA aproximada: 1:48:52
# [██████████████████████████████████████------------]
#
# ======================================================================
# >>> Ingestando GREEN 2023-08
# [green 2023-08] BORRADOS anteriores: 60649
# [green 2023-08] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2023-08.parquet
# [green 2023-08] INSERTADAS: 60649 filas
# green 2023-08: 60649 filas
# Tiempo: 0:00:13
# Progreso: 188/240
# ETA aproximada: 1:46:18
# [███████████████████████████████████████-----------]
#
# ======================================================================
# >>> Ingestando GREEN 2023-09
# [green 2023-09] BORRADOS anteriores: 65471
# [green 2023-09] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2023-09.parquet
# [green 2023-09] INSERTADAS: 65471 filas
# green 2023-09: 65471 filas
# Tiempo: 0:00:13
# Progreso: 189/240
# ETA aproximada: 1:43:46
# [███████████████████████████████████████-----------]
#
# ======================================================================
# >>> Ingestando GREEN 2023-10
# [green 2023-10] BORRADOS anteriores: 66177
# [green 2023-10] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2023-10.parquet
# [green 2023-10] INSERTADAS: 66177 filas
# green 2023-10: 66177 filas
# Tiempo: 0:00:13
# Progreso: 190/240
# ETA aproximada: 1:41:15
# [███████████████████████████████████████-----------]
#
# ======================================================================
# >>> Ingestando GREEN 2023-11
# [green 2023-11] BORRADOS anteriores: 64025
# [green 2023-11] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2023-11.parquet
# [green 2023-11] INSERTADAS: 64025 filas
# green 2023-11: 64025 filas
# Tiempo: 0:00:13
# Progreso: 191/240
# ETA aproximada: 1:38:46
# [███████████████████████████████████████-----------]
#
# ======================================================================
# >>> Ingestando GREEN 2023-12
# [green 2023-12] BORRADOS anteriores: 64215
# [green 2023-12] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2023-12.parquet
# [green 2023-12] INSERTADAS: 64215 filas
# green 2023-12: 64215 filas
# Tiempo: 0:00:13
# Progreso: 192/240
# ETA aproximada: 1:36:18
# [████████████████████████████████████████----------]
#
# ======================================================================
# >>> Ingestando YELLOW 2024-01
# [yellow 2024-01] BORRADOS anteriores: 2964624
# [yellow 2024-01] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2024-01.parquet
# [yellow 2024-01] INSERTADAS: 2964624 filas
# yellow 2024-01: 2964624 filas
# Tiempo: 0:02:41
# Progreso: 193/240
# ETA aproximada: 1:34:28
# [████████████████████████████████████████----------]
#
# ======================================================================
# >>> Ingestando YELLOW 2024-02
# [yellow 2024-02] BORRADOS anteriores: 3007526
# [yellow 2024-02] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2024-02.parquet
# [yellow 2024-02] INSERTADAS: 3007526 filas
# yellow 2024-02: 3007526 filas
# Tiempo: 0:02:36
# Progreso: 194/240
# ETA aproximada: 1:32:36
# [████████████████████████████████████████----------]
#
# ======================================================================
# >>> Ingestando YELLOW 2024-03
# [yellow 2024-03] BORRADOS anteriores: 3582628
# [yellow 2024-03] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2024-03.parquet
# [yellow 2024-03] INSERTADAS: 3582628 filas
# yellow 2024-03: 3582628 filas
# Tiempo: 0:02:38
# Progreso: 195/240
# ETA aproximada: 1:30:44
# [████████████████████████████████████████----------]
#
# ======================================================================
# >>> Ingestando YELLOW 2024-04
# [yellow 2024-04] BORRADOS anteriores: 3514289
# [yellow 2024-04] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2024-04.parquet
# [yellow 2024-04] INSERTADAS: 3514289 filas
# yellow 2024-04: 3514289 filas
# Tiempo: 0:02:39
# Progreso: 196/240
# ETA aproximada: 1:28:52
# [████████████████████████████████████████----------]
#
# ======================================================================
# >>> Ingestando YELLOW 2024-05
# [yellow 2024-05] BORRADOS anteriores: 3723833
# [yellow 2024-05] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2024-05.parquet
# [yellow 2024-05] INSERTADAS: 3723833 filas
# yellow 2024-05: 3723833 filas
# Tiempo: 0:02:37
# Progreso: 197/240
# ETA aproximada: 1:26:58
# [█████████████████████████████████████████---------]
#
# ======================================================================
# >>> Ingestando YELLOW 2024-06
# [yellow 2024-06] BORRADOS anteriores: 3539193
# [yellow 2024-06] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2024-06.parquet
# [yellow 2024-06] INSERTADAS: 3539193 filas
# yellow 2024-06: 3539193 filas
# Tiempo: 0:02:39
# Progreso: 198/240
# ETA aproximada: 1:25:05
# [█████████████████████████████████████████---------]
#
# ======================================================================
# >>> Ingestando YELLOW 2024-07
# [yellow 2024-07] BORRADOS anteriores: 3076903
# [yellow 2024-07] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2024-07.parquet
# [yellow 2024-07] INSERTADAS: 3076903 filas
# yellow 2024-07: 3076903 filas
# Tiempo: 0:02:38
# Progreso: 199/240
# ETA aproximada: 1:23:11
# [█████████████████████████████████████████---------]
#
# ======================================================================
# >>> Ingestando YELLOW 2024-08
# [yellow 2024-08] BORRADOS anteriores: 2979183
# [yellow 2024-08] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2024-08.parquet
# [yellow 2024-08] INSERTADAS: 2979183 filas
# yellow 2024-08: 2979183 filas
# Tiempo: 0:02:37
# Progreso: 200/240
# ETA aproximada: 1:21:16
# [█████████████████████████████████████████---------]
#
# ======================================================================
# >>> Ingestando YELLOW 2024-09
# [yellow 2024-09] BORRADOS anteriores: 3633030
# [yellow 2024-09] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2024-09.parquet
# [yellow 2024-09] INSERTADAS: 3633030 filas
# yellow 2024-09: 3633030 filas
# Tiempo: 0:02:40
# Progreso: 201/240
# ETA aproximada: 1:19:22
# [█████████████████████████████████████████---------]
#
# ======================================================================
# >>> Ingestando YELLOW 2024-10
# [yellow 2024-10] BORRADOS anteriores: 3833771
# [yellow 2024-10] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2024-10.parquet
# [yellow 2024-10] INSERTADAS: 3833771 filas
# yellow 2024-10: 3833771 filas
# Tiempo: 0:02:40
# Progreso: 202/240
# ETA aproximada: 1:17:27
# [██████████████████████████████████████████--------]
#
# ======================================================================
# >>> Ingestando YELLOW 2024-11
# [yellow 2024-11] BORRADOS anteriores: 3646369
# [yellow 2024-11] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2024-11.parquet
# [yellow 2024-11] INSERTADAS: 3646369 filas
# yellow 2024-11: 3646369 filas
# Tiempo: 0:02:45
# Progreso: 203/240
# ETA aproximada: 1:15:33
# [██████████████████████████████████████████--------]
#
# ======================================================================
# >>> Ingestando YELLOW 2024-12
# [yellow 2024-12] BORRADOS anteriores: 3668371
# [yellow 2024-12] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2024-12.parquet
# [yellow 2024-12] INSERTADAS: 3668371 filas
# yellow 2024-12: 3668371 filas
# Tiempo: 0:02:51
# Progreso: 204/240
# ETA aproximada: 1:13:39
# [██████████████████████████████████████████--------]
#
# ======================================================================
# >>> Ingestando GREEN 2024-01
# [green 2024-08] BORRADOS anteriores: 51771
# [green 2024-08] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2024-08.parquet
# [green 2024-08] INSERTADAS: 51771 filas
# green 2024-08: 51771 filas
# Tiempo: 0:00:13
# Progreso: 212/240
# ETA aproximada: 0:55:22
# [████████████████████████████████████████████------]
#
# ======================================================================
# >>> Ingestando GREEN 2024-09
# [green 2024-09] BORRADOS anteriores: 54440
# [green 2024-09] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2024-09.parquet
# [green 2024-09] INSERTADAS: 54440 filas
# green 2024-09: 54440 filas
# Tiempo: 0:00:13
# Progreso: 213/240
# ETA aproximada: 0:53:10
# [████████████████████████████████████████████------]
#
# ======================================================================
# >>> Ingestando GREEN 2024-10
# [green 2024-10] BORRADOS anteriores: 56147
# [green 2024-10] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2024-10.parquet
# [green 2024-10] INSERTADAS: 56147 filas
# green 2024-10: 56147 filas
# Tiempo: 0:00:13
# Progreso: 214/240
# ETA aproximada: 0:50:59
# [████████████████████████████████████████████------]
#
# ======================================================================
# >>> Ingestando GREEN 2024-11
# [green 2024-11] BORRADOS anteriores: 52222
# [green 2024-11] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2024-11.parquet
# [green 2024-11] INSERTADAS: 52222 filas
# green 2024-11: 52222 filas
# Tiempo: 0:00:13
# Progreso: 215/240
# ETA aproximada: 0:48:49
# [████████████████████████████████████████████------]
#
# ======================================================================
# >>> Ingestando GREEN 2024-12
# [green 2024-12] BORRADOS anteriores: 53994
# [green 2024-12] Leyendo parquet: /home/jovyan/work/data/trip-data/green_tripdata_2024-12.parquet
# [green 2024-12] INSERTADAS: 53994 filas
# green 2024-12: 53994 filas
# Tiempo: 0:00:13
# Progreso: 216/240
# ETA aproximada: 0:46:40
# [█████████████████████████████████████████████-----]
#
# ======================================================================
# >>> Ingestando YELLOW 2025-01
# [yellow 2025-01] BORRADOS anteriores: 0
# [yellow 2025-01] Leyendo parquet: /home/jovyan/work/data/trip-data/yellow_tripdata_2025-01.parquet
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[4], line 26
#      23 print(f">>> Ingestando {svc.upper()} {y}-{m:02d}")
#      25 start = time.time()
# ---> 26 cnt = ingest_month(svc, y, m)
#      27 elapsed = time.time() - start
#      29 done += 1
#
# Cell In[3], line 94, in ingest_month(service, year, month)
#      88 # 4) Escribir a Postgres (optimizado)
#      89 table = f"raw.{service}_taxi_trip"
#      90 (dfn.write
#      91     .mode("append")
#      92     .option("batchsize", 10000)     # 👈 CAMBIO 2: batches más grandes
#      93     .option("numPartitions", 8)     # 👈 CAMBIO 3: control de paralelismo JDBC
# ---> 94     .jdbc(PG_URL, table, properties=PG_PROPS))
#      96 cnt = dfn.count()
#      97 print(f"[{service} {year}-{month:02d}] INSERTADAS: {cnt} filas")
#
# File /usr/local/spark/python/pyspark/sql/readwriter.py:1984, in DataFrameWriter.jdbc(self, url, table, mode, properties)
#    1982 for k in properties:
#    1983     jprop.setProperty(k, properties[k])
# -> 1984 self.mode(mode)._jwrite.jdbc(url, table, jprop)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/spark/python/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: Column cbd_congestion_fee not found in schema Some(StructType(StructField(VendorID,LongType,true),StructField(pickup_datetime,TimestampType,true),StructField(dropoff_datetime,TimestampType,true),StructField(passenger_count,LongType,true),StructField(trip_distance,DoubleType,true),StructField(RatecodeID,LongType,true),StructField(store_and_fwd_flag,StringType,true),StructField(PULocationID,LongType,true),StructField(DOLocationID,LongType,true),StructField(payment_type,LongType,true),StructField(fare_amount,DoubleType,true),StructField(extra,DoubleType,true),StructField(mta_tax,DoubleType,true),StructField(tip_amount,DoubleType,true),StructField(tolls_amount,DoubleType,true),StructField(improvement_surcharge,DoubleType,true),StructField(total_amount,DoubleType,true),StructField(congestion_surcharge,IntegerType,true),StructField(airport_fee,IntegerType,true),StructField(service_type,StringType,false),StructField(source_year,IntegerType,false),StructField(source_month,IntegerType,false),StructField(ingested_at_utc,TimestampType,false),StructField(run_id,StringType,false))).
